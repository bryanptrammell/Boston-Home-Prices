# %%
#Step 1) Write a Python script that fetches holiday data and saves it as a csv file named "holidays.csv". To obtain the data, you can either parse the API or screen scrape the Nager.Date site.
import csv
import requests
def fetch_holiday_data(country_code="US", year=2023):
    url = f"https://date.nager.at/api/v3/publicholidays/{year}/{country_code}"
    response = requests.get(url)
    return response.json()

def save_to_csv(data):
    with open("holidays.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["name", "date", "type", "global"])
        for holiday in data:
            writer.writerow([holiday["name"], holiday["date"], holiday.get("type", ""), holiday["global"]])

if __name__ == "__main__":
    data = fetch_holiday_data()
    save_to_csv(data)

# %%
#Step 2 and 3- Using the csv file from 1), write a Python function that returns a list of dictionaries of the next 10 upcoming U.S. holidays and dates,
import csv
from datetime import datetime

def get_next_10_holidays(global_filter=None):
    with open("holidays.csv", "r") as f:
        reader = csv.DictReader(f)
        holidays_list = [row for row in reader]

    today = datetime.today().date()
    upcoming_holidays = [h for h in holidays_list if datetime.strptime(h["date"], '%Y-%m-%d').date() >= today]
    
    if global_filter is not None:
        upcoming_holidays = [h for h in upcoming_holidays if h["global"] == str(global_filter)]
    
    return upcoming_holidays[:10]

# Test
get_next_10_holidays(global_filter = True)
# Out:
# [{'name': 'Veterans Day', 'date': '2023-11-10', 'type': '', 'global': 'True'},
#  {'name': 'Thanksgiving Day',
#   'date': '2023-11-23',
#   'type': '',
#   'global': 'True'},
#  {'name': 'Christmas Day', 'date': '2023-12-25', 'type': '', 'global': 'True'}]

# %%
import requests
from datetime import datetime

def fetch_holiday_data(country_code="US", year=2023):
    url = f"https://date.nager.at/api/v3/publicholidays/{year}/{country_code}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch data for country: {country_code}")
        return []
    try:
        return response.json()
    except JSONDecodeError:
        print(f"Failed to decode JSON for country: {country_code}")
        return []

def compare_holidays_with_country(comparison_country="None"):
    current_year = datetime.now().year
    comparison_holidays = fetch_holiday_data(country_code=comparison_country, year=current_year)
    comparison_dates = {h["date"]: h["name"] for h in comparison_holidays}

    common_holidays = {}
    holiday_counts = {}  # To count how many countries celebrate each holiday

    countries = ["AT", "BE", "BG", "BR", "CA", "CH", "CN", "CO", "CZ", "DE", "DK", "EE", "ES", "FI", "FR", "GB", "GR", "HR", "HU", "IE", "IN", "IT", "JP", "KR", "MX", "NL", "NO", "NZ", "PL", "PT", "RO", "RU", "SE", "SG", "SI", "SK", "ZA", "US"]

    for country in countries:
        country_holidays = fetch_holiday_data(country_code=country, year=current_year)
        country_dates = {h["date"]: h["name"] for h in country_holidays}
        common_dates = set(comparison_dates.keys()).intersection(set(country_dates.keys()))

        for date in common_dates:
            holiday_counts[date] = holiday_counts.get(date, 0) + 1

        if common_dates:
            common_holidays[country] = [{"date": date, "name": comparison_dates[date]} for date in common_dates]

    # Determine global holidays
    threshold = len(countries) // 2
    global_holidays = {date for date, count in holiday_counts.items() if count > threshold}

    sorted_countries = sorted(common_holidays.items(), key=lambda x: len(x[1]), reverse=True)[:10]
    result = [{"country": k, "holidays": [{"name": h["name"], "date": h["date"], "type": h.get("type", "Public"), "global": h["date"] in global_holidays} for h in v]} for k, v in sorted_countries]

    return result

# Test
(compare_holidays_with_country(comparison_country="CA"))
# Out:
# Failed to fetch data for country: IN
# [{'country': 'CA',
#   'holidays': [{'name': 'National Holiday',
#     'date': '2023-06-24',
#     'type': 'Public',
#     'global': False},
#    {'name': "Saint George's Day",
#     'date': '2023-04-23',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Discovery Day',
#     'date': '2023-08-21',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Labour Day',
#     'date': '2023-09-04',
#     'type': 'Public',
#     'global': False},
#    {'name': "Orangemen's Day",
#     'date': '2023-07-12',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Thanksgiving',
#     'date': '2023-10-09',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Remembrance Day',
#     'date': '2023-11-11',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Saskatchewan Day',
#     'date': '2023-08-07',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Victoria Day',
#     'date': '2023-05-22',
#     'type': 'Public',
#     'global': False},
#    {'name': 'National Day for Truth and Reconciliation',
#     'date': '2023-09-30',
#     'type': 'Public',
#     'global': False},
#    {'name': 'National Aboriginal Day',
#     'date': '2023-06-21',
#     'type': 'Public',
#     'global': False},
#    {'name': "Saint Patrick's Day",
#     'date': '2023-03-17',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Family Day',
#     'date': '2023-02-20',
#     'type': 'Public',
#     'global': False},
#    {'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Canada Day',
#     'date': '2023-07-01',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'GB',
#   'holidays': [{'name': "Saint Patrick's Day",
#     'date': '2023-03-17',
#     'type': 'Public',
#     'global': False},
#    {'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Saskatchewan Day',
#     'date': '2023-08-07',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': "Orangemen's Day",
#     'date': '2023-07-12',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'ES',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'National Holiday',
#     'date': '2023-06-24',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Thanksgiving',
#     'date': '2023-10-09',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'IE',
#   'holidays': [{'name': "Saint Patrick's Day",
#     'date': '2023-03-17',
#     'type': 'Public',
#     'global': False},
#    {'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Saskatchewan Day',
#     'date': '2023-08-07',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'BE',
#   'holidays': [{'name': 'Remembrance Day',
#     'date': '2023-11-11',
#     'type': 'Public',
#     'global': False},
#    {'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'CO',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Saskatchewan Day',
#     'date': '2023-08-07',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Discovery Day',
#     'date': '2023-08-21',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Victoria Day',
#     'date': '2023-05-22',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'FI',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'National Holiday',
#     'date': '2023-06-24',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'SE',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'National Holiday',
#     'date': '2023-06-24',
#     'type': 'Public',
#     'global': False},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'CH',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]},
#  {'country': 'CZ',
#   'holidays': [{'name': "New Year's Day",
#     'date': '2023-01-01',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Good Friday',
#     'date': '2023-04-07',
#     'type': 'Public',
#     'global': True},
#    {'name': "St. Stephen's Day",
#     'date': '2023-12-26',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Easter Monday',
#     'date': '2023-04-10',
#     'type': 'Public',
#     'global': True},
#    {'name': 'Christmas Day',
#     'date': '2023-12-25',
#     'type': 'Public',
#     'global': True}]}]

# %%
#Step 5 - Write a Python function that returns a list of dictionaries of the top 10 countries ranked by the number of upcoming holiday dates (in the next 364 days) they have in common with a given comparison country

def fetch_holiday_data(country_code="US", year=2023):
    url = f"https://date.nager.at/api/v3/publicholidays/{year}/{country_code}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch data for country: {country_code}")
        return []
    try:
        return response.json()
    except JSONDecodeError:
        print(f"Failed to decode JSON for country: {country_code}")
        return []

def most_common_countries(comparison_country="US"):
    current_year = datetime.now().year
    comparison_holidays = fetch_holiday_data(country_code=comparison_country, year=current_year)
    comparison_dates = {h["date"] for h in comparison_holidays}

    common_count = {}
    countries = ["AT", "BE", "BG", "BR", "CA", "CH", "CN", "CO", "CZ", "DE", "DK", "EE", "ES", "FI", "FR", "GB", "GR", "HR", "HU", "IE", "IN", "IT", "JP", "KR", "MX", "NL", "NO", "NZ", "PL", "PT", "RO", "RU", "SE", "SG", "SI", "SK", "ZA", "US"]
    for country in countries:
        country_holidays = fetch_holiday_data(country_code=country, year=current_year)
        common_dates = comparison_dates.intersection({h["date"] for h in country_holidays if "date" in h})
        common_count[country] = len(common_dates)

    sorted_countries = sorted(common_count.items(), key=lambda x: x[1], reverse=True)[:10]
    result = [{"country": k, "common_dates": v} for k, v in sorted_countries]
    return result

# Test
(most_common_countries())
# Out:
# Failed to fetch data for country: IN
# [{'country': 'US', 'common_dates': 12},
#  {'country': 'CA', 'common_dates': 5},
#  {'country': 'CH', 'common_dates': 4},
#  {'country': 'ES', 'common_dates': 4},
#  {'country': 'GB', 'common_dates': 4},
#  {'country': 'BE', 'common_dates': 3},
#  {'country': 'BR', 'common_dates': 3},
#  {'country': 'CO', 'common_dates': 3},
#  {'country': 'DE', 'common_dates': 3},
#  {'country': 'DK', 'common_dates': 3}]
